# %% [markdown]
# # About the data set analysed
# This dataset contains only internal displaced persons living in camps and camp-like settlements. During Round 38, site assessments were conducted in 2,380 locations. Assessed locations included 309 camps and camp-like settlements as well as 2,071 locations where internally displaced persons were living among host communities (down from 2,089 in Round 37). The purpose was to better understand the gaps in services provided and the needs of the affected population. Site assessments included an analysis of sector-wide needs, shelter and non-food items, water, sanitation and hygiene (WASH), food and nutrition, health, education, livelihood, security, communication and protection.
#
# In response to the need for accurate information on internally displaced persons (IDPs) in Nigeria, the International Organization for Migration (IOM) began implementing the Displacement Tracking Matrix (DTM) project in July 2014. The project is supporting the Government of Nigeria and other humanitarian response partners to conduct IDPs assessments in a systematic way as well as to establish a profile of the IDP population.
#
# This analysis basically was drwan from the survey conducted in 2021 (Round 38)
#
# THE FOLLOWING ARE THE INSIGHTS DERIVED FROM THE ANALYSIS:
#
# 1. 93% of households have no shelter in their IDP Camps
#
# 2. 25% being highest percentage of refugees live in their own made shelter
# 3. 79% of households have no access to electricity
# 4. 40% of refugees live indoors (solid walls)
# 5. 39% of households have private living area while 22% have none
# 6. 43% have mosquito nets
# 7. 47% of children attend school in the refugee camps
# 8. 58% of refugees live in collective settlements
# 9. 58% of idp camps do not a proper management body like the governement or religious bodies
# 10. 68% have WASH Support (WASH is an intervention group)
# 11. 44% of the camps have not CCCM Organization
# 12. 58% of refugees have health support while the rest do not.
# 13. Only 60% have food support
# 14. Only 58% have food support
# 15. Only 55% still own lands
# 16. 36% of the shelter idps have is the self-made/make-shift type
# 17. 56% of the idps have been formerly displaced
# 18. 65% of idps have no Natural hazards, 15% is as a result of flood, 11% is storm while the rest is fire.
# 19. 92% of idps still have homes to return to while 8% do not.
# 20. 60% of idps can return if there is improved security, 18% will return if they can have lands to live and cultivate, 10% wants to go back to school,others have other varied reasons.
# 21. 89% of idps still wish to go back home
# 22. 47% of idps don not have blankets or mats to sleep on.
# 23. 86% of idps lack a three square meal
# 24. 55% of idps have about 10 to 15 litres of water each person per day
# 25. There is the availability of water at about 96% in the camps
# 26. 84% complain there are no hygieneic toilets available
# 27. 53% said the INGOs provide their health services.
# 28. 58% of idps wish to engage in farmin but there are no lands.
# 29. Evidently, Borno state is most affected by this scourge with 96% of the households coming from there while Adamawa has just 1%
# 30. 34% of idps engage in petty trading. They can be assisted with credit facilities which will enhance their living standards. While 31% engage in manual labour.
# 31. 81% of idps said there are no secondary health care facilities for Adults.
# 32. 73% of idps said there are no secondary health care facilities for children.
# 33. 50% of the idps indicated that the health facilities are located offsite, hence health facilities should be established onsite for easy access.
# 34. 93% decleared the presense of health facilities. Hence the health car workers deserve commendation.
# 35. 64% declared their major health challenge is the issue of Malaria, 18% is fever, 13% is cough. Hence, donor agencies and the government should intensify efforts at this direction.
# 36. 50% of idps source their foods with their money.
# 37. 73% idps indicated that garbages are burnt there which possess health challenges for them.
# 38. 74% said there is the campaign for hygiene however the idp management body has to better.
# 39. 55% decleared the is the rampancy of open defecation.
# 40. There are no hand washing stations according to 55% of the idps which suggest there os the high chances of disease spread especially in this period of covid-19 pandemic.
#
# RECOMMENDATIONS
# Based on the above insights, my recommendations are that the government and other intervention bodies should intensify efforts in the areas of food supply, hygiene, credit facilities for traders, health facilities, shelter etc in view of the mounting security challenge forcing more people to flee their homes to settle in IDP camps.

# %%
# Loading relevant libraries
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
#Loading the dataset
dtm = pd.read_excel('displacement-round-38.xlsx')

# %%
# Show all columns
pd.set_option('display.max_columns',None)

# %%
dtm.head(3)
# Out:
#          Snapshot date        Country   Country Code    DTM Round  \
# 0       #date+reported  #country+name  #country+code  #meta+round
# 1  2021-07-30 00:00:00        Nigeria            NGA           38
# 2  2021-07-30 00:00:00        Nigeria            NGA           38
#
#                   Date       State State_Pcode         LGA   LGA Pcode  \
# 0        #date+occured  #adm1+Name  #adm1+code  #adm2+name  #adm2+code
# 1  2021-07-08 00:00:00     ADAMAWA       NG002  YOLA SOUTH    NG002021
# 2  2021-07-07 00:00:00     ADAMAWA       NG002  YOLA SOUTH    NG002021
#
#          Ward CODs_Ward_Pcode         SiteID        Site Name Longitude  \
# 0  #adm3+name      #adm3+code  #meta+site+id  #meta+site+name  #geo+lon
# 1     NAMTARI     NG002021008        AD_S003     MALKOHI CAMP  12.38553
# 2     NAMTARI     NG002021008        AD_S004  MALKOHI VILLAGE  12.37614
#
#    Latitude             Gooogle Map Link             Site Status  \
# ...

# %%
dtm.drop(0, inplace = True)

# %%
dtm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 309 entries, 1 to 309
# Columns: 106 entries, Snapshot date to Serious problem due to lack information
# dtypes: float64(1), object(105)
# memory usage: 258.3+ KB

# %%
# To fetch all int columns
int_col = []
for x in dtm.dtypes.index:
    if dtm.dtypes[x] == 'object':
        int_col.append(x)
        
int_col
# Out:
# ['Snapshot date',
#  'Country',
#  'Country Code',
#  'DTM Round',
#  'Date',
#  'State',
#  'State_Pcode',
#  'LGA',
#  'LGA Pcode',
#  'Ward',
#  'CODs_Ward_Pcode',
#  'SiteID',
#  'Site Name',
#  'Longitude',
#  'Latitude',
#  'Gooogle Map Link',
#  'Site Status',
#  'Site Type',
#  'Site Classification',
#  'Site Area',
#  'Site Management Agency',
#  'SMA type',
#  'Registration Activity',
#  'WASH Support',
#  'CCCM Support',
#  'CCCM_Organization',
#  'HEALTH Support',
#  'SHELTER Support',
#  'NFI Support ',
#  'FOOD Support',
#  'PROTECTION Support',
#  'EDUCATION Support',
#  'LIVELIHOOD Support',
#  'PSS SUPPORT',
#  'PSS_ORGANIZATION',
#  'Land Ownership',
#  'Most Common Type of Shelter',
#  'Number of Households',
#  'Number of Individuals',
#  'Boys (<1)',
#  'Girls (<1)',
#  'Boys (1 - 5 y)',
#  'Girls (1 - 5 y)',
#  'Boys 6to12y',
#  'Girls 6to12y',
#  'Boys 13to17y',
#  'Girls 13to17y',
#  'Men (18 - 59 y)',
#  'Women (18 - 59 y)',
#  '(Elderly men 60+ y)',
# ...

# %%
dtm.shape
# Out:
# (309, 106)

# %%
# Check for null values
dtm.isna().sum()
# Out:
# Snapshot date                               0
# Country                                     0
# Country Code                                0
# DTM Round                                   0
# Date                                        0
#                                            ..
# Livestock on site                           0
# IDPs have access to land for cultivation    0
# Most trusted source of Info                 0
# Main topic community is requesting info     0
# Serious problem due to lack information     0
# Length: 106, dtype: int64

# %%
# Display all object data type columns
int_col = []
for x in dtm.dtypes.index:
    if dtm.dtypes[x] == 'object':
        int_col.append(x)
        
int_col
# Out:
# ['Date',
#  'State',
#  'LGA',
#  'Ward',
#  'Site Name',
#  'Site Status',
#  'Site Type',
#  'Site Classification',
#  'Site Management Agency',
#  'SMA type',
#  'Registration Activity',
#  'WASH Support',
#  'CCCM Support',
#  'CCCM_Organization',
#  'HEALTH Support',
#  'SHELTER Support',
#  'NFI Support ',
#  'FOOD Support',
#  'PROTECTION Support',
#  'EDUCATION Support',
#  'LIVELIHOOD Support',
#  'PSS SUPPORT',
#  'PSS_ORGANIZATION',
#  'Land Ownership',
#  'Most Common Type of Shelter',
#  'Number of Households',
#  'Have IDPs been displaced previously',
#  'Reason for displacement of Majority',
#  'Natural Hazard Risks',
#  'Intended Area of Return',
#  'Reasons to Return Home',
#  'Reasons NOT to Return Home',
#  '% HH living outside (no shelter)',
#  '% HH living in EmS',
#  '% HH living in makeshift/self-made shelter',
#  '% HH living indoors (solid walls)',
#  '% HH have access to electricity',
#  '% HH have access to safe cooking facilities',
# ...

# %%
# Rename some columns
dtm.rename(columns = {'# of HH with source of income':'HH with source of income', '# of functioning toilets': 'Functioning toilets'}, inplace  = True)

# %%
#Drop some columns
dtm.drop(columns = ['Snapshot date', 'Country','Country Code','DTM Round', 'State_Pcode', 'LGA Pcode', 'CODs_Ward_Pcode','SiteID','Longitude','Latitude','Gooogle Map Link'], inplace = True)

# %%
dtm.shape
# Out:
# (309, 95)

# %%
# Removing the sq.m string on the Site area column
dtm['Site Area'] = dtm['Site Area'].str.rstrip('sq.m')

# %%
# Removing spaces
dtm['Site Area'] = dtm['Site Area'].str.strip()

# %%
# Removing comma in some values
dtm['Site Area']=dtm['Site Area'].str.replace(',','')

# %%
# Removing some other spaces between values in some rows
dtm['Site Area'] = dtm['Site Area'].str.replace(" ","")

# %%
# Removing sq.m in some rows
dtm['Site Area'] = dtm['Site Area'].str.replace('sq.m', '')
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_16056/762860185.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dtm['Site Area'] = dtm['Site Area'].str.replace('sq.m', '')

# %%
# Converting the column to integer data type
dtm['Site Area'] = dtm['Site Area'].astype(int)

# %%
# Converting the column to integer data type
dtm['Number of Households'] = dtm['Number of Households'].astype(int)

# %%
dtm['Number of Individuals'] = dtm['Number of Individuals'].astype(int)

# %%
# Converted the following columns to integer data type for the ease of computational analysis.
dtm['Boys (<1)'] = dtm['Boys (<1)'].astype(int)
dtm['Girls (<1)'] = dtm['Girls (<1)'].astype(int)
dtm['Boys (1 - 5 y)'] = dtm['Boys (1 - 5 y)'].astype(int)
dtm['Girls (1 - 5 y)'] = dtm['Girls (1 - 5 y)'].astype(int)
dtm['Boys 6to12y'] = dtm['Boys 6to12y'].astype(int)
dtm['Girls 6to12y'] = dtm['Girls 6to12y'].astype(int)
dtm['Boys 13to17y'] = dtm['Boys 13to17y'].astype(int)
dtm['Girls 13to17y'] = dtm['Girls 13to17y'].astype(int)
dtm['Men (18 - 59 y)'] = dtm['Men (18 - 59 y)'].astype(int)
dtm['Women (18 - 59 y)'] = dtm['Women (18 - 59 y)'].astype(int)
dtm['(Elderly men 60+ y)'] = dtm['(Elderly men 60+ y)'].astype(int)
dtm['(Elderly women 60+ y)'] = dtm['(Elderly women 60+ y)'].astype(int)
dtm['HH with source of income'] = dtm['HH with source of income'].astype(int)
dtm['Functioning toilets'] = dtm['Functioning toilets'].astype(int)

# %%
# 93% of households have no shelter in their IDP Camps
dtm['% HH living outside (no shelter)'].value_counts(normalize = True)
# Out:
# None                  0.948220
# Less 25%              0.035599
# Between 25% - 50 %    0.009709
# Between 51% - 75%     0.006472
# Name: % HH living outside (no shelter), dtype: float64

# %%
# Recode the values of the column
dtm['% HH living outside (no shelter)'] = dtm['% HH living outside (no shelter)'].map({"none":"None", "<25%":"Less 25%", "25%_50%":"Between 25% - 50 %", "51%_75%":"Between 51% - 75%"})

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="% HH living outside (no shelter)", data=dtm)
# Out:
# <AxesSubplot:xlabel='% HH living outside (no shelter)', ylabel='count'>

# %%
dtm['% HH living in EmS'].value_counts(normalize = True)
# Out:
# None                 0.388350
# Less 25%             0.190939
# Over 75%             0.184466
# Between 51% - 75%    0.142395
# Between 25% - 50%    0.093851
# Name: % HH living in EmS, dtype: float64

# %%
# Recode the values of the column
dtm['% HH living in EmS'] = dtm['% HH living in EmS'].map({"<25%": "Less 25%", "none":"None", ">75%":"Over 75%","51%_75%":"Between 51% - 75%", "25%_50%":"Between 25% - 50%"})

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="% HH living in EmS", data=dtm)
# Out:
# <AxesSubplot:xlabel='% HH living in EmS', ylabel='count'>

# %%
# 25% being highest percentage of refugees live in their own made shelter
dtm['% HH living in makeshift/self-made shelter'].value_counts(normalize = True)
# Out:
# <25%       0.281553
# none       0.262136
# >75%       0.177994
# 51%_75%    0.174757
# 25%_50%    0.103560
# Name: % HH living in makeshift/self-made shelter, dtype: float64

# %%
# Recode the values of the column
dtm['% HH living in makeshift/self-made shelter'] = dtm['% HH living in makeshift/self-made shelter'].map({"<25%": "Less 25%", "none":"None", ">75%":"Over 75%","51%_75%":"Between 51% - 75%", "25%_50%":"Between 25% - 50%"})

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="% HH living in makeshift/self-made shelter", data=dtm)
# Out:
# <AxesSubplot:xlabel='% HH living in makeshift/self-made shelter', ylabel='count'>

# %%
# 79% of households have no access to electricity
dtm['% HH have access to electricity'].value_counts(normalize = True)
# Out:
# none       0.799353
# <25%       0.097087
# 25%_50%    0.055016
# 51%_75%    0.038835
# >75%       0.009709
# Name: % HH have access to electricity, dtype: float64

# %%
# Recode the values of the column
dtm['% HH have access to electricity'] = dtm['% HH have access to electricity'].map({"<25%": "Less 25%", "none":"None", ">75%":"Over 75%","51%_75%":"Between 51% - 75%", "25%_50%":"Between 25% - 50%"})

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="% HH have access to electricity", data=dtm)
# Out:
# <AxesSubplot:xlabel='% HH have access to electricity', ylabel='count'>

# %%
# 40% of refugees live indoors (solid walls)
dtm['% HH living indoors (solid walls)'].value_counts(normalize = True)
# Out:
# none       0.404531
# <25%       0.281553
# >75%       0.139159
# 51%_75%    0.100324
# 25%_50%    0.074434
# Name: % HH living indoors (solid walls), dtype: float64

# %%
# Recode the values of the column
dtm['% HH living indoors (solid walls)'] = dtm['% HH living indoors (solid walls)'].map({"<25%": "Less 25%", "none":"None", ">75%":"Over 75%","51%_75%":"Between 51% - 75%", "25%_50%":"Between 25% - 50%"})

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="% HH living indoors (solid walls)", data=dtm)
# Out:
# <AxesSubplot:xlabel='% HH living indoors (solid walls)', ylabel='count'>

# %%
# 39% of households have private living area while 22% have none
dtm['% HH have private living area'].value_counts(normalize = True)
# Out:
# <25%       0.391586
# 25%_50%    0.291262
# none       0.226537
# 51%_75%    0.080906
# >75%       0.009709
# Name: % HH have private living area, dtype: float64

# %%
# Recode the values of the column
dtm['% HH have private living area'] = dtm['% HH have private living area'].map({"<25%": "Less 25%", "none":"None", ">75%":"Over 75%","51%_75%":"Between 51% - 75%", "25%_50%":"Between 25% - 50%"})

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="% HH have private living area", data=dtm)
# Out:
# <AxesSubplot:xlabel='% HH have private living area', ylabel='count'>

# %%
# 43% have mosquito nets
dtm['% HH have mosquito nets'].value_counts(normalize = True)
# Out:
# <25%       0.430421
# 25%_50%    0.372168
# 51%_75%    0.142395
# none       0.032362
# >75%       0.022654
# Name: % HH have mosquito nets, dtype: float64

# %%
# Recode the values of the column
dtm['% HH have mosquito nets'] = dtm['% HH have mosquito nets'].map({"<25%": "Less 25%", "none":"None", ">75%":"Over 75%","51%_75%":"Between 51% - 75%", "25%_50%":"Between 25% - 50%"})

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="% HH have mosquito nets", data=dtm)
# Out:
# <AxesSubplot:xlabel='% HH have mosquito nets', ylabel='count'>

# %%
# 47% of children attend school in the refugee camps
dtm['% of children attending school'].value_counts(normalize = True)
# Out:
# Between 25% - 50%    0.472492
# Between 51% - 75%    0.233010
# Less 25%             0.233010
# None                 0.032362
# Over 75%             0.029126
# Name: % of children attending school, dtype: float64

# %%
# Recode the values of the column
dtm['% of children attending school'] = dtm['% of children attending school'].map({ "25% -50%":"Between 25% - 50%", "51% - 75%":"Between 51% - 75%", "<25%": "Less 25%", "none":"None", ">75%":"Over 75%"})

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="% of children attending school", data=dtm)
# Out:
# <AxesSubplot:xlabel='% of children attending school', ylabel='count'>

# %%
# Creating Year, Month and Day columns from the Date column
dtm['Year'] = pd.DatetimeIndex(dtm['Date']).year
dtm['Month'] = pd.DatetimeIndex(dtm['Date']).month
dtm['Day'] = pd.DatetimeIndex(dtm['Date']).day

# %%
dtm[['Boys (<1)','Girls (<1)','Boys (1 - 5 y)','Girls (1 - 5 y)','Boys 6to12y','Girls 6to12y','Boys 13to17y','Girls 13to17y','Men (18 - 59 y)','Women (18 - 59 y)','(Elderly men 60+ y)','(Elderly women 60+ y)']]
# Out:
#      Boys (<1)  Girls (<1)  Boys (1 - 5 y)  Girls (1 - 5 y)  Boys 6to12y  \
# 1           43          46              45               59           67
# 2           63          82             129              139          171
# 3           68          85             168              199          519
# 4            0           0               0                0            0
# 5            4           5              12               12            4
# ..         ...         ...             ...              ...          ...
# 305         42          47              41               68           50
# 306         43          47              41               73           51
# 307         18          23              19               25           24
# 308         16          23              17               23           21
# 309         25          29              31               37           39
#
#      Girls 6to12y  Boys 13to17y  Girls 13to17y  Men (18 - 59 y)  \
# ...

# %%
dtm[['Boys (<1)','Girls (<1)','Boys (1 - 5 y)','Girls (1 - 5 y)','Boys 6to12y','Girls 6to12y','Boys 13to17y','Girls 13to17y','Men (18 - 59 y)','Women (18 - 59 y)','(Elderly men 60+ y)','(Elderly women 60+ y)']]

# %%
fig = px.treemap(dtm, path=[px.Constant("State"), 'Boys (<1)','Girls (<1)','Boys (1 - 5 y)','Girls (1 - 5 y)','Boys 6to12y','Girls 6to12y','Boys 13to17y','Girls 13to17y','Men (18 - 59 y)','Women (18 - 59 y)','(Elderly men 60+ y)','(Elderly women 60+ y)'], values='Number of Households',
                  color='Number of Households', hover_data=['Site Type'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(dtm['Number of Households'], weights=dtm['Functioning toilets']),title='Demographic Information Treemap Plot')
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
# <div>                            <div id="9703ed4a-adaa-4617-8b5a-473a3edf4948" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9703ed4a-adaa-4617-8b5a-473a3edf4948")) {                    Plotly.newPlot(                        "9703ed4a-adaa-4617-8b5a-473a3edf4948",                        [{"branchvalues":"total","customdata":[["Collective Settlement/Centre",1.0],["Collective Settlement/Centre",10.0],["Collective Settlement/Centre",18.0],["Collective Settlement/Centre",1.0],["Collective Settlement/Centre",5.0],["camp",7.0],["camp",19.0],["Collective Settlement/Centre",8.0],["Collective Settlement/Centre",8.0],["camp",14.0],["Collective Settlement/Centre",14.0],["camp",13.0],["Collective Settlement/Centre",12.0],["Collective Settlement/Centre",16.0]
# ...

# %%
plt.figure(figsize=(15,5))
sns.barplot(y=dtm['Site Area'],x=dtm['State'],color='blue',label='Site Area')
sns.barplot(y=dtm['Number of Individuals'],x=dtm['State'],color='g',label='Number of Individuals')
plt.xticks(rotation=90)
plt.title('Site Area in Square Meter by Number of Individuals in the States')
plt.legend( ncol=2, facecolor='gray', edgecolor='#f6f5f5', loc='upper left', fontsize=16)
plt.show()

# %%
dtm['LGA'].value_counts(normalize = True)[:10]
# Out:
# JERE               0.255663
# MAIDUGURI M. C.    0.216828
# DIKWA              0.055016
# KONDUGA            0.045307
# MONGUNO            0.038835
# DAMBOA             0.035599
# GWOZA              0.032362
# GIREI              0.029126
# DAMATURU           0.025890
# YOLA SOUTH         0.022654
# Name: LGA, dtype: float64

# %%
plt.figure(figsize=(35, 6))
sns.countplot(x='LGA', data=dtm)
# Out:
# <AxesSubplot:xlabel='LGA', ylabel='count'>

# %%
dtm['Ward'].value_counts()[:10]
# Out:
# MAISANDARI        29
# DUSUMAN           23
# OLD MAIDUGURI     21
# DIKWA             17
# MASHAMARI         16
# BOLORI  I         14
# MONGUNO           12
# DAMBOA            11
# BALE GALTIMARI    10
# BOLORI  II        10
# Name: Ward, dtype: int64

# %%
plt.figure(figsize=(35, 6))
sns.countplot(x='Ward', data=dtm)
# Out:
# <AxesSubplot:xlabel='Ward', ylabel='count'>

# %%
dtm['Site Name'].value_counts()[:10]
# Out:
# FULATARI CAMP            2
# VERTINARY                2
# FULATARI                 2
# KLAGARU CAMP             1
# PAMPAS STREET CAMP       1
# RAILWAY TERMINUS CAMP    1
# MARTE CAMP               1
# UNITY CAMP               1
# OLD INEC CAMP            1
# ALHAJI BASHIR CAMP       1
# Name: Site Name, dtype: int64

# %%
dtm['Site Status'].value_counts(normalize = True)[:10]
# Out:
# informal    0.851133
# formal      0.148867
# Name: Site Status, dtype: float64

# %%
dtm['Site Classification'].value_counts(normalize = True)[:10]
# Out:
# Spontaneous    0.721683
# Planned        0.278317
# Name: Site Classification, dtype: float64

# %%
dtm.pivot_table(index = 'State', values =['Site Status', 'Site Status', 'Site Classification'],aggfunc = 'count')
# Out:
#          Site Classification  Site Status  Site Status
# State
# ADAMAWA                   30           30           30
# BAUCHI                     5            5            5
# BORNO                    241          241          241
# TARABA                    13           13           13
# YOBE                      20           20           20

# %%
dtm[(dtm['State'] == 'YOBE') &(dtm['Site Classification'] == 'Spontaneous')]
# Out:
#                     Date State       LGA                              Ward  \
# 290  2021-07-04 00:00:00  YOBE  DAMATURU                  KUKARETA/WARSALA
# 291  2021-07-04 00:00:00  YOBE  DAMATURU  MAISANDARI/WAZIRI IBRAHIM ESTATE
# 292  2021-07-03 00:00:00  YOBE  DAMATURU                      GABIR/MADURI
# 293  2021-07-04 00:00:00  YOBE  DAMATURU  MAISANDARI/WAZIRI IBRAHIM ESTATE
# 294  2021-07-04 00:00:00  YOBE  DAMATURU                  DAMATURU CENTRAL
# 295  2021-07-04 00:00:00  YOBE  YUNUSARI                  BULTUWA/MAR/YARO
# 296  2021-07-07 00:00:00  YOBE     NGURU                     GARBI/BAMBORI
# 297  2021-07-04 00:00:00  YOBE  DAMATURU                  DAMATURU CENTRAL
# 298  2021-07-05 00:00:00  YOBE      FUNE       DOGON KUKA/GISHIWARI/GUNUNU
# 299  2021-07-09 00:00:00  YOBE     GUJBA                             GUJBA
# 300  2021-07-09 00:00:00  YOBE     GUJBA                             GUJBA
# ...

# %%
dtmad = dtm[['State', 'Site Classification']]

# %%
dtmad[(dtmad['State'] == 'ADAMAWA') & (dtmad['Site Classification']=='Spontaneous')].count()
# Out:
# State                  24
# Site Classification    24
# dtype: int64

# %%
dtmad[(dtmad['State'] == 'ADAMAWA') & (dtmad['Site Classification']=='Planned')].count()
# Out:
# State                  6
# Site Classification    6
# dtype: int64

# %%
dtmad[(dtmad['State'] == 'YOBE') & (dtmad['Site Classification']=='Planned')].count()
# Out:
# State                  0
# Site Classification    0
# dtype: int64

# %%
dtmad[(dtmad['State'] == 'YOBE') & (dtmad['Site Classification']=='Spontaneous')].count()
# Out:
# State                  20
# Site Classification    20
# dtype: int64

# %%
dtmad[(dtmad['State'] == 'BORNO') & (dtmad['Site Classification']=='Spontaneous')].count()
# Out:
# State                  161
# Site Classification    161
# dtype: int64

# %%
dtmad[(dtmad['State'] == 'BORNO') & (dtmad['Site Classification']=='Planned')].count()
# Out:
# State                  80
# Site Classification    80
# dtype: int64

# %%
dtmad[(dtmad['State'] == 'BAUCHI') & (dtmad['Site Classification']=='Spontaneous')].count()
# Out:
# State                  5
# Site Classification    5
# dtype: int64

# %%
dtmad[(dtmad['State'] == 'BAUCHI') & (dtmad['Site Classification']=='Planned')].count()
# Out:
# State                  0
# Site Classification    0
# dtype: int64

# %%
dtmad[(dtmad['State'] == 'TARABA') & (dtmad['Site Classification']=='Spontaneous')].count()
# Out:
# State                  13
# Site Classification    13
# dtype: int64

# %%
dtmad[(dtmad['State'] == 'TARABA') & (dtmad['Site Classification']=='Planned')].count()
# Out:
# State                  0
# Site Classification    0
# dtype: int64

# %%
dtm.pivot_table(index = 'State', values =['Site Status', 'Site Type'],aggfunc = 'count')
# Out:
#          Site Status  Site Type
# State
# ADAMAWA           30         30
# BAUCHI             5          5
# BORNO            241        241
# TARABA            13         13
# YOBE              20         20

# %%
# 58% of refugees live in collective settlements
dtm['Site Type'].value_counts(normalize = True)
# Out:
# Collective Settlement/Centre    0.582524
# camp                            0.381877
# Camp                            0.029126
# transitional centre             0.006472
# Name: Site Type, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='Site Type', data=dtm)
# Out:
# <AxesSubplot:xlabel='Site Type', ylabel='count'>

# %%
dtm['Site Management Agency'].value_counts(normalize = True)
# Out:
# no     0.543689
# yes    0.456311
# Name: Site Management Agency, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Site Management Agency', data=dtm)
# Out:
# <AxesSubplot:xlabel='Site Management Agency', ylabel='count'>

# %%
# 58% of idp camps do not a proper management body like the governement or religious bodies
dtm['SMA type'].value_counts(normalize = True)
# Out:
# none                0.543689
# ingo                0.194175
# un                  0.116505
# government          0.090615
# local ngo           0.051780
# religious entity    0.003236
# Name: SMA type, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='SMA type', data=dtm)
# Out:
# <AxesSubplot:xlabel='SMA type', ylabel='count'>

# %%
dtm['Registration Activity'].value_counts(normalize = True)
# Out:
# yes    0.76699
# no     0.23301
# Name: Registration Activity, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Registration Activity', data=dtm)
# Out:
# <AxesSubplot:xlabel='Registration Activity', ylabel='count'>

# %%
# 68% have WASH Support (WASH is an intervention group)
dtm['WASH Support'].value_counts(normalize = True)
# Out:
# yes    0.68932
# no     0.31068
# Name: WASH Support, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='WASH Support', data=dtm)
# Out:
# <AxesSubplot:xlabel='WASH Support', ylabel='count'>

# %%
dtm['CCCM Support'].value_counts(normalize = True)
# Out:
# yes    0.556634
# no     0.443366
# Name: CCCM Support, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='CCCM Support', data=dtm)
# Out:
# <AxesSubplot:xlabel='CCCM Support', ylabel='count'>

# %%
# 44% of the camps have not CCCM Organization
dtm['CCCM_Organization'].value_counts(normalize = True)
# Out:
# No CCCM Organization     0.443366
# iom                      0.233010
# nrc                      0.139159
# acted                    0.051780
# SALIENT INTERNATIONAL    0.045307
# locdin                   0.035599
# intersos                 0.029126
# shi                      0.012945
# IOM                      0.003236
# PPGW                     0.003236
# SHI                      0.003236
# Name: CCCM_Organization, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='CCCM_Organization', data=dtm)
# Out:
# <AxesSubplot:xlabel='CCCM_Organization', ylabel='count'>

# %%
# 58% of refugees have health support while the rest do not.
dtm['HEALTH Support'].value_counts(normalize = True)
# Out:
# no     0.582524
# yes    0.417476
# Name: HEALTH Support, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='HEALTH Support', data=dtm)
# Out:
# <AxesSubplot:xlabel='HEALTH Support', ylabel='count'>

# %%
dtm['SHELTER Support'].value_counts(normalize = True)
# Out:
# yes    0.679612
# no     0.320388
# Name: SHELTER Support, dtype: float64

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='SHELTER Support', data=dtm)
# Out:
# <AxesSubplot:xlabel='SHELTER Support', ylabel='count'>

# %%
# Only 60% have food support
dtm['FOOD Support'].value_counts(normalize = True)
# Out:
# yes    0.601942
# no     0.398058
# Name: FOOD Support, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='FOOD Support', data=dtm)
# Out:
# <AxesSubplot:xlabel='FOOD Support', ylabel='count'>

# %%
# Only 60% have protection support
dtm['PROTECTION Support'].value_counts(normalize = True)
# Out:
# yes    0.605178
# no     0.394822
# Name: PROTECTION Support, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='PROTECTION Support', data=dtm)
# Out:
# <AxesSubplot:xlabel='PROTECTION Support', ylabel='count'>

# %%
# Only 58% have food support
dtm['EDUCATION Support'].value_counts(normalize = True)
# Out:
# no     0.582524
# yes    0.417476
# Name: EDUCATION Support, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='EDUCATION Support', data=dtm)
# Out:
# <AxesSubplot:xlabel='EDUCATION Support', ylabel='count'>

# %%
dtm['LIVELIHOOD Support'].value_counts(normalize = True)
# Out:
# no     0.582524
# yes    0.417476
# Name: LIVELIHOOD Support, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='LIVELIHOOD Support', data=dtm)
# Out:
# <AxesSubplot:xlabel='LIVELIHOOD Support', ylabel='count'>

# %%
dtm['PSS SUPPORT'].value_counts(normalize = True)
# Out:
# no     0.673139
# yes    0.326861
# Name: PSS SUPPORT, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='PSS SUPPORT', data=dtm)
# Out:
# <AxesSubplot:xlabel='PSS SUPPORT', ylabel='count'>

# %%
# Only 55% still own lands
dtm['Land Ownership'].value_counts(normalize = True)
# Out:
# private building     0.550162
# Public/Government    0.427184
# Private Building     0.016181
# Ancestral            0.006472
# Name: Land Ownership, dtype: float64

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Land Ownership', data=dtm)
# Out:
# <AxesSubplot:xlabel='Land Ownership', ylabel='count'>

# %%
dtm['PSS_ORGANIZATION'].value_counts(normalize = True)
# Out:
# No PSS ORGANIZATION    0.673139
# IOM                    0.220065
# IOM IRC                0.022654
# Gold pram              0.019417
# MSF                    0.019417
# JDPC                   0.009709
# IOM other              0.006472
# IOM ICRC               0.006472
# ICRC UNICEF            0.003236
# UNFPA                  0.003236
# MSF UNFPA UNICEF       0.003236
# MSF UNFPA              0.003236
# IMC                    0.003236
# UNICEF                 0.003236
# IOM UNFPA UNICEF       0.003236
# Name: PSS_ORGANIZATION, dtype: float64

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='PSS_ORGANIZATION', data=dtm)
# Out:
# <AxesSubplot:xlabel='PSS_ORGANIZATION', ylabel='count'>

# %%
# 36% of the shelter idps have is the self-made/make-shift type
dtm['Most Common Type of Shelter'].value_counts(normalize = True)
# Out:
# Self-made/Makeshift shelter    0.362460
# emergency shelter              0.339806
# Host family house              0.071197
# individual house               0.055016
# government building            0.048544
# school building                0.038835
# rented house                   0.038835
# open lot                       0.035599
# community center               0.009709
# Name: Most Common Type of Shelter, dtype: float64

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='Most Common Type of Shelter', data=dtm)
# Out:
# <AxesSubplot:xlabel='Most Common Type of Shelter', ylabel='count'>

# %%
# 56% of the idps have been formerly displaced
dtm['Have IDPs been displaced previously'].value_counts(normalize = True)
# Out:
# no     0.566343
# yes    0.433657
# Name: Have IDPs been displaced previously, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Have IDPs been displaced previously', data=dtm)
# Out:
# <AxesSubplot:xlabel='Have IDPs been displaced previously', ylabel='count'>

# %%
# 65% of idps have no Natural hazards, 15% is as a result of flood, 11% is storm while the rest is fire.
dtm['Natural Hazard Risks'].value_counts(normalize = True)
# Out:
# none     0.653722
# flood    0.155340
# storm    0.110032
# fire     0.080906
# Name: Natural Hazard Risks, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Natural Hazard Risks', data=dtm)
# Out:
# <AxesSubplot:xlabel='Natural Hazard Risks', ylabel='count'>

# %%
# 92% of idps still have homes to return to while 8% do not.
dtm['Intended Area of Return'].value_counts(normalize = True)
# Out:
# place of origin    0.92233
# none stay here     0.07767
# Name: Intended Area of Return, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Intended Area of Return', data=dtm)
# Out:
# <AxesSubplot:xlabel='Intended Area of Return', ylabel='count'>

# %%
# 60% of idps can return if there is improved security, 18% will return if they can have lands to live and cultivate, 10% wants to go back to school,others have other varied reasons. 
dtm['Reasons to Return Home'].value_counts(normalize = True)
# Out:
# improved security            0.601942
# access to land               0.184466
# I don't want to go back      0.100324
# access to better services    0.048544
# to join family members       0.042071
# rebuild personal shelter     0.019417
# free transport available     0.003236
# Name: Reasons to Return Home, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='Reasons to Return Home', data=dtm)
# Out:
# <AxesSubplot:xlabel='Reasons to Return Home', ylabel='count'>

# %%
# 89% of idps still wish to go back home
dtm['Reasons NOT to Return Home'].value_counts(normalize = True)
# Out:
# I want to go back             0.899676
# no access to initial place    0.061489
# house damaged                 0.019417
# better living condition       0.019417
# Name: Reasons NOT to Return Home, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='Reasons NOT to Return Home', data=dtm)
# Out:
# <AxesSubplot:xlabel='Reasons NOT to Return Home', ylabel='count'>

# %%
# 47% of idps don not have blankets or mats to sleep on.
dtm['Most needed NFI'].value_counts(normalize = True)
# Out:
# Blankets/Mats       0.472492
# kitchen sets        0.194175
# mosquito nets       0.165049
# soap                0.067961
# mattress            0.038835
# hygiene kits        0.035599
# Bucket/Jerry Can    0.016181
# solar lamps         0.009709
# Name: Most needed NFI, dtype: float64

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='Most needed NFI', data=dtm)
# Out:
# <AxesSubplot:xlabel='Most needed NFI', ylabel='count'>

# %%
# 86% of idps lack a three square meal
dtm['Most Unmet Needs'].value_counts(normalize = True)
# Out:
# Food                       0.864078
# Shelter                    0.048544
# Medical services           0.022654
# NFI                        0.019417
# Livelihood                 0.012945
# sanitation and hygiene     0.012945
# Portable drinking water    0.009709
# None                       0.006472
# Education                  0.003236
# Name: Most Unmet Needs, dtype: float64

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='Most Unmet Needs', data=dtm)
# Out:
# <AxesSubplot:xlabel='Most Unmet Needs', ylabel='count'>

# %%
dtm['Location of site main water source'].value_counts(normalize = True)
# Out:
# on-site (<10 minutes)     0.660194
# off-site (<10 minutes)    0.242718
# on-site (>10 minutes)     0.061489
# off-site (>10 minutes)    0.035599
# Name: Location of site main water source, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='Location of site main water source', data=dtm)
# Out:
# <AxesSubplot:xlabel='Location of site main water source', ylabel='count'>

# %%
dtm['Main drinking water source'].value_counts(normalize = True)
# Out:
# piped water supply      0.663430
# hand pumps              0.210356
# water truck             0.067961
# protected well          0.016181
# unprotected well        0.012945
# lake/dam                0.006472
# surface water           0.006472
# ponds/canals            0.006472
# spring                  0.003236
# none                    0.003236
# bottled/sachet water    0.003236
# Name: Main drinking water source, dtype: float64

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='Main drinking water source', data=dtm)
# Out:
# <AxesSubplot:xlabel='Main drinking water source', ylabel='count'>

# %%
# 55% of idps have about 10 to 15 litres of water each person per day
dtm['Avg amount of water available /day/person'].value_counts(normalize = True)
# Out:
# 10-15ltr    0.553398
# >15ltr      0.300971
#  5-10ltr    0.093851
# unknown     0.045307
# <5ltr       0.003236
# 5-10tr      0.003236
# Name: Avg amount of water available /day/person, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='Avg amount of water available /day/person', data=dtm)
# Out:
# <AxesSubplot:xlabel='Avg amount of water available /day/person', ylabel='count'>

# %%
# There is the availability of water at about 96% in the camps 
dtm['Is drinking water potable'].value_counts(normalize = True)
# Out:
# yes    0.964401
# no     0.035599
# Name: Is drinking water potable, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Is drinking water potable', data=dtm)
# Out:
# <AxesSubplot:xlabel='Is drinking water potable', ylabel='count'>

# %%
dtm['Complaints about drinking water quality'].value_counts(normalize = True)
# Out:
# no     0.964401
# yes    0.035599
# Name: Complaints about drinking water quality, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Complaints about drinking water quality', data=dtm)
# Out:
# <AxesSubplot:xlabel='Complaints about drinking water quality', ylabel='count'>

# %%
# 84% complain there are no hygieneic toilets available
dtm['Condition of most of the toilets'].value_counts(normalize = True)
# Out:
# not so good (not hygienic)    0.844660
# good (hygienic)               0.106796
# unknown                       0.035599
# non usable                    0.012945
# Name: Condition of most of the toilets, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Condition of most of the toilets', data=dtm)
# Out:
# <AxesSubplot:xlabel='Condition of most of the toilets', ylabel='count'>

# %%
# 73% idps indicated that garbages are burnt there which possess health challenges for them.
dtm['Main garbage disposal'].value_counts(normalize = True)
# Out:
# burning                     0.731392
# no waste disposal system    0.152104
# garbage pit                 0.116505
# Name: Main garbage disposal, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Main garbage disposal', data=dtm)
# Out:
# <AxesSubplot:xlabel='Main garbage disposal', ylabel='count'>

# %%
dtm['Garbage and solid waste problem'].value_counts(normalize = True)
# Out:
# yes    0.605178
# no     0.394822
# Name: Garbage and solid waste problem, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Garbage and solid waste problem', data=dtm)
# Out:
# <AxesSubplot:xlabel='Garbage and solid waste problem', ylabel='count'>

# %%
# 74% said there is the campaign for hygiene however the idp management body has to better.
dtm['Hygiene promotion campaign'].value_counts(normalize = True)
# Out:
# yes    0.7411
# no     0.2589
# Name: Hygiene promotion campaign, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Hygiene promotion campaign', data=dtm)
# Out:
# <AxesSubplot:xlabel='Hygiene promotion campaign', ylabel='count'>

# %%
# There are no hand washing stations according to 55% of the idps which suggest there os the high chances of disease spread especially in this period of covid-19 pandemic.
dtm['Availability of hand-washing station'].value_counts(normalize = True)
# Out:
# none                            0.559871
# yes_but_no_soap/water_inside    0.245955
# yes                             0.177994
# yes but no soap/water inside    0.016181
# Name: Availability of hand-washing station, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='Availability of hand-washing station', data=dtm)
# Out:
# <AxesSubplot:xlabel='Availability of hand-washing station', ylabel='count'>

# %%
# 55% decleared the is the rampancy of open defecation.
dtm['Evidence of open defecation'].value_counts(normalize = True)
# Out:
# yes    0.556634
# no     0.443366
# Name: Evidence of open defecation, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Evidence of open defecation', data=dtm)
# Out:
# <AxesSubplot:xlabel='Evidence of open defecation', ylabel='count'>

# %%
dtm['Access to food'].value_counts(normalize = True)
# Out:
# yes onsite     0.449838
# yes offsite    0.343042
# no             0.207120
# Name: Access to food, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Access to food', data=dtm)
# Out:
# <AxesSubplot:xlabel='Access to food', ylabel='count'>

# %%
dtm['Access to market near from the site'].value_counts(normalize = True)
# Out:
# yes    0.902913
# no     0.097087
# Name: Access to market near from the site, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Access to market near from the site', data=dtm)
# Out:
# <AxesSubplot:xlabel='Access to market near from the site', ylabel='count'>

# %%
dtm['Frequency of food distribution'].value_counts(normalize = True)
# Out:
# once a month    0.417476
# irregular       0.385113
# never           0.174757
# once a week     0.009709
# everyday        0.006472
# twice a week    0.006472
# Name: Frequency of food distribution, dtype: float64

# %%
plt.figure(figsize=(16, 4))
sns.countplot(x='Frequency of food distribution', data=dtm)
# Out:
# <AxesSubplot:xlabel='Frequency of food distribution', ylabel='count'>

# %%
# 50% of idps source their foods with their money.
dtm['Most common source for obtaining food'].value_counts(normalize = True)
# Out:
# cash (personal money)      0.501618
# distribution               0.381877
# cultivated                 0.106796
# host community donation    0.006472
# none                       0.003236
# Name: Most common source for obtaining food, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='Most common source for obtaining food', data=dtm)
# Out:
# <AxesSubplot:xlabel='Most common source for obtaining food', ylabel='count'>

# %%
dtm['Screening for malnutrition'].value_counts(normalize = True)
# Out:
# yes    0.66343
# no     0.33657
# Name: Screening for malnutrition, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Screening for malnutrition', data=dtm)
# Out:
# <AxesSubplot:xlabel='Screening for malnutrition', ylabel='count'>

# %%
# 64% declared their major health challenge is the issue of Malaria, 18% is fever, 13% is cough. Hence, donor agencies and the government should intensify efforts at this direction. 
dtm['Most health problem'].value_counts(normalize = True)
# Out:
# malaria            0.647249
# fever              0.184466
# cough              0.139159
# diarrhea           0.016181
# none               0.006472
# hepatitis          0.003236
# wound infection    0.003236
# Name: Most health problem, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='Most health problem', data=dtm)
# Out:
# <AxesSubplot:xlabel='Most health problem', ylabel='count'>

# %%
dtm['Regular access to medicine'].value_counts(normalize = True)
# Out:
# yes    0.867314
# no     0.132686
# Name: Regular access to medicine, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Regular access to medicine', data=dtm)
# Out:
# <AxesSubplot:xlabel='Regular access to medicine', ylabel='count'>

# %%
# 93% decleared the presense of health facilities. Hence the health car workers deserve commendation.
dtm['Access to health facility'].value_counts(normalize = True)
# Out:
# yes    0.928803
# no     0.071197
# Name: Access to health facility, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Access to health facility', data=dtm)
# Out:
# <AxesSubplot:xlabel='Access to health facility', ylabel='count'>

# %%
# 50% of the idps indicated that the health facilities are located offsite, hence health facilities should be established onsite for easy access. 
dtm['Location of health facilities'].value_counts(normalize = True)
# Out:
# off-site (< 3 km)    0.508091
# on-site (< 3 km)     0.271845
# off-site (> 3 km)    0.129450
# on-site (> 3 km)     0.064725
# none                 0.012945
# mobile clinic        0.012945
# Name: Location of health facilities, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Location of health facilities', data=dtm)
# Out:
# <AxesSubplot:xlabel='Location of health facilities', ylabel='count'>

# %%
dtm['Main provider of health facilities'].value_counts(normalize = True)
# Out:
# government      0.501618
# ingo            0.411003
# ngo             0.045307
# local clinic    0.029126
# UN              0.006472
# none            0.006472
# Name: Main provider of health facilities, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Main provider of health facilities', data=dtm)
# Out:
# <AxesSubplot:xlabel='Main provider of health facilities', ylabel='count'>

# %%
# 53% said the INGOs provide their health services.
dtm['Main Provider of Health Services'].value_counts(normalize = True)
# Out:
# ingo            0.530744
# government      0.362460
# ngo             0.055016
# local clinic    0.038835
# UN              0.006472
# none            0.006472
# Name: Main Provider of Health Services, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Main Provider of Health Services', data=dtm)
# Out:
# <AxesSubplot:xlabel='Main Provider of Health Services', ylabel='count'>

# %%
dtm['Primary Health Care for Children'].value_counts(normalize = True)
# Out:
# Yes    0.915858
# No     0.051780
# yes    0.032362
# Name: Primary Health Care for Children, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Primary Health Care for Children', data=dtm)
# Out:
# <AxesSubplot:xlabel='Primary Health Care for Children', ylabel='count'>

# %%
dtm['Primary Health Care for Adult'].value_counts(normalize = True)
# Out:
# Yes    0.860841
# No     0.106796
# yes    0.032362
# Name: Primary Health Care for Adult, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Primary Health Care for Adult', data=dtm)
# Out:
# <AxesSubplot:xlabel='Primary Health Care for Adult', ylabel='count'>

# %%
# 73% of idps said there are no secondary health care facilities for children.
dtm['Secondary Health Care for Children'].value_counts(normalize = True)
# Out:
# No     0.731392
# Yes    0.236246
# no     0.022654
# yes    0.009709
# Name: Secondary Health Care for Children, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Secondary Health Care for Children', data=dtm)
# Out:
# <AxesSubplot:xlabel='Secondary Health Care for Children', ylabel='count'>

# %%
# 81% of idps said there are no secondary health care facilities for Adults.
dtm['Secondary Health Care for Adult'].value_counts(normalize = True)
# Out:
# No     0.812298
# Yes    0.155340
# no     0.032362
# Name: Secondary Health Care for Adult, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Secondary Health Care for Adult', data=dtm)
# Out:
# <AxesSubplot:xlabel='Secondary Health Care for Adult', ylabel='count'>

# %%
dtm['Traditional Health Care'].value_counts(normalize = True)
# Out:
# No     0.941748
# no     0.032362
# Yes    0.025890
# Name: Traditional Health Care, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Traditional Health Care', data=dtm)
# Out:
# <AxesSubplot:xlabel='Traditional Health Care', ylabel='count'>

# %%
dtm['Access to education services'].value_counts(normalize = True)
# Out:
# yes    0.983819
# no     0.016181
# Name: Access to education services, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Access to education services', data=dtm)
# Out:
# <AxesSubplot:xlabel='Access to education services', ylabel='count'>

# %%
dtm['Location of education facilities'].value_counts(normalize = True)
# Out:
# offsite    0.634304
# onsite     0.346278
# none       0.019417
# Name: Location of education facilities, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Location of education facilities', data=dtm)
# Out:
# <AxesSubplot:xlabel='Location of education facilities', ylabel='count'>

# %%
dtm['% of children attending school'].value_counts(normalize = True)
# Out:
# Between 25% - 50%    0.472492
# Between 51% - 75%    0.233010
# Less 25%             0.233010
# None                 0.032362
# Over 75%             0.029126
# Name: % of children attending school, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='% of children attending school', data=dtm)
# Out:
# <AxesSubplot:xlabel='% of children attending school', ylabel='count'>

# %%
# 34% of idps engage in petty trading. They can be assisted with credit facilities which will enhance their living standards. While 31% engage in manual labour.
dtm['Occupation of majority of IDPs'].value_counts(normalize = True)
# Out:
# petty trade            0.349515
# daily labourer         0.310680
# farming                0.233010
# collecting firewood    0.042071
# agro-pastoralism       0.025890
# pastoralism            0.019417
# none                   0.012945
# fishing                0.006472
# Name: Occupation of majority of IDPs, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='Occupation of majority of IDPs', data=dtm)
# Out:
# <AxesSubplot:xlabel='Occupation of majority of IDPs', ylabel='count'>

# %%
dtm['Access to income generating activities'].value_counts(normalize = True)
# Out:
# yes    0.987055
# no     0.012945
# Name: Access to income generating activities, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Access to income generating activities', data=dtm)
# Out:
# <AxesSubplot:xlabel='Access to income generating activities', ylabel='count'>

# %%
dtm['Livestock on site'].value_counts(normalize = True)
# Out:
# yes    0.838188
# no     0.161812
# Name: Livestock on site, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Livestock on site', data=dtm)
# Out:
# <AxesSubplot:xlabel='Livestock on site', ylabel='count'>

# %%
# 58% of idps wish to engage in farmin but there are no lands.
dtm['IDPs have access to land for cultivation'].value_counts(normalize = True)
# Out:
# no     0.588997
# yes    0.411003
# Name: IDPs have access to land for cultivation, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='IDPs have access to land for cultivation', data=dtm)
# Out:
# <AxesSubplot:xlabel='IDPs have access to land for cultivation', ylabel='count'>

# %%
dtm['Most trusted source of Info'].value_counts(normalize = True)
# Out:
# friends, neighbors and family    0.543689
# local leader/community leader    0.304207
# aid worker                       0.048544
# religious leader                 0.045307
# traditional leader               0.029126
# government official              0.025890
# military official                0.003236
# Name: Most trusted source of Info, dtype: float64

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='Most trusted source of Info', data=dtm)
# Out:
# <AxesSubplot:xlabel='Most trusted source of Info', ylabel='count'>

# %%
dtm['Main topic community is requesting info'].value_counts(normalize = True)
# Out:
# distribution                    0.446602
# access to services              0.249191
# situation in areas of origin    0.097087
# other relief assistance         0.093851
# safety and security             0.090615
# shelter                         0.009709
# none                            0.006472
# registration                    0.003236
# how to get information          0.003236
# Name: Main topic community is requesting info, dtype: float64

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='Main topic community is requesting info', data=dtm)
# Out:
# <AxesSubplot:xlabel='Main topic community is requesting info', ylabel='count'>

# %%
dtm['Serious problem due to lack information'].value_counts(normalize = True)
# Out:
# no     0.873786
# yes    0.126214
# Name: Serious problem due to lack information, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Serious problem due to lack information', data=dtm)
# Out:
# <AxesSubplot:xlabel='Serious problem due to lack information', ylabel='count'>

# %%
dtm.pivot_table(index = 'State', values = ['Site Area','Number of Individuals']).round(0).sort_values(by= 'Site Area',ascending = False)
# Out:
#          Number of Individuals  Site Area
# State
# BORNO                   3471.0    75585.0
# YOBE                     842.0    58572.0
# ADAMAWA                  629.0    36708.0
# BAUCHI                   332.0    27247.0
# TARABA                   434.0    12450.0

# %%
sns.lmplot(data = dtm, x = 'Site Area', y = 'Number of Individuals', hue = 'State')

# %%
dtm.pivot_table(index = 'State', values  = ['Boys (<1)','Girls (<1)','Boys (1 - 5 y)','Girls (1 - 5 y)','Boys 6to12y','Girls 6to12y','Boys 13to17y','Girls 13to17y','Men (18 - 59 y)','Women (18 - 59 y)','(Elderly men 60+ y)','(Elderly women 60+ y)']).round(0).sort_values(by = 'Girls (<1)', ascending = False)
# Out:
#          (Elderly men 60+ y)  (Elderly women 60+ y)  Boys (1 - 5 y)  \
# State
# BORNO                   69.0                   78.0           275.0
# YOBE                    16.0                   20.0            49.0
# TARABA                   6.0                    7.0            27.0
# ADAMAWA                  9.0                   11.0            38.0
# BAUCHI                   1.0                    4.0            15.0
#
#          Boys (<1)  Boys 13to17y  Boys 6to12y  Girls (1 - 5 y)  Girls (<1)  \
# State
# BORNO         93.0         227.0        285.0            321.0       110.0
# YOBE          34.0          71.0         62.0             60.0        41.0
# TARABA        14.0          37.0         37.0             35.0        18.0
# ADAMAWA       14.0          61.0         55.0             47.0        17.0
# BAUCHI        10.0          30.0         34.0             20.0         9.0
#
#          Girls 13to17y  Girls 6to12y  Men (18 - 59 y)  Women (18 - 59 y)
# State
# ...

# %%
# Evidently, Borno state is most affected by this scourge with 96% of the households coming from there while Adamawa has just 1%.
dtm.groupby('State').sum()['Number of Households'].sort_values(ascending = False)/198705*100
# Out:
# State
# BORNO      96.357414
# ADAMAWA     1.674341
# YOBE        1.371380
# TARABA      0.455952
# BAUCHI      0.140912
# Name: Number of Households, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x="State", y="Number of Households", data=dtm)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Number of Households'>

# %%
dtm.pivot_table(index = 'State', values  = ['Boys (<1)','Girls (<1)','Boys (1 - 5 y)','Girls (1 - 5 y)','Boys 6to12y','Girls 6to12y','Boys 13to17y','Girls 13to17y','Men (18 - 59 y)','Women (18 - 59 y)','(Elderly men 60+ y)','(Elderly women 60+ y)']).round(0).sort_values(by = 'Girls (<1)', ascending = False).plot(kind = 'bar', figsize = (12,8), title = 'Demographic Plot')
# Out:
# <AxesSubplot:title={'center':'Demographic Plot'}, xlabel='State'>
